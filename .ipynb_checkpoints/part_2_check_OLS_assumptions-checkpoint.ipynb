# %% [markdown]
# # Part 1 - Data Cleaning

# %% [markdown]
# ## Importing the relevant libraries

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
sns.set()

# %% [markdown]
# ## Loading the raw data

# %%
raw_data = pd.read_csv('Red.csv')

# %%
raw_data.head()
# Out:
#                                  Name  Country     Region  \
# 0                        Pomerol 2011   France    Pomerol
# 1                          Lirac 2017   France      Lirac
# 2  Erta e China Rosso di Toscana 2015    Italy    Toscana
# 3                      Bardolino 2019    Italy  Bardolino
# 4      Ried Scheibner Pinot Noir 2016  Austria  Carnuntum
#
#                   Winery  Rating  NumberOfRatings  Price    Year
# 0  Château La Providence     4.2              100  95.00  2011.0
# 1     Château Mont-Redon     4.3              100  15.50  2017.0
# 2             Renzo Masi     3.9              100   7.45  2015.0
# 3             Cavalchina     3.5              100   8.72  2019.0
# 4            Markowitsch     3.9              100  29.15  2016.0

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Exploring the descriptive statistics of the variables

# %%
raw_data.describe(include='all')
# Out:
#                            Name Country Region     Winery       Rating  \
# count                      8666    8666   8666       8666  8666.000000
# unique                     6721      30    624       2714          NaN
# top     Cabernet Sauvignon 2017   Italy  Rioja  Errazuriz          NaN
# freq                         43    2650    325         40          NaN
# mean                        NaN     NaN    NaN        NaN     3.890342
# std                         NaN     NaN    NaN        NaN     0.308548
# min                         NaN     NaN    NaN        NaN     2.500000
# 25%                         NaN     NaN    NaN        NaN     3.700000
# 50%                         NaN     NaN    NaN        NaN     3.900000
# 75%                         NaN     NaN    NaN        NaN     4.100000
# max                         NaN     NaN    NaN        NaN     4.800000
#
#         NumberOfRatings        Price         Year
# count       8666.000000  8666.000000  8658.000000
# unique              NaN          NaN          NaN
# top                 NaN          NaN          NaN
# freq                NaN          NaN          NaN
# mean         415.287445    39.145065  2014.818434
# std          899.726373    84.936307     3.281252
# min           25.000000     3.550000  1988.000000
# 25%           66.000000    10.680000  2014.000000
# 50%          157.000000    18.200000  2016.000000
# 75%          401.000000    38.142500  2017.000000
# max        20293.000000  3410.790000  2019.000000

# %%
raw_data.dtypes
# Out:
# Name                object
# Country             object
# Region              object
# Winery              object
# Rating             float64
# NumberOfRatings      int64
# Price              float64
# Year                object
# dtype: object

# %% [markdown]
# #### Converting Year to Float from Object

# %%
raw_data['Year'] = pd.to_numeric(raw_data['Year'], errors='coerce')

# %% [markdown]
# ### Dealing with missing values

# %%
raw_data.isnull().sum()
# Out:
# Name               0
# Country            0
# Region             0
# Winery             0
# Rating             0
# NumberOfRatings    0
# Price              0
# Year               8
# dtype: int64

# %%
data_no_mv = raw_data.dropna(axis=0)

# %%
data_no_mv.describe(include='all')
# Out:
#                            Name Country Region     Winery       Rating  \
# count                      8658    8658   8658       8658  8658.000000
# unique                     6713      30    623       2713          NaN
# top     Cabernet Sauvignon 2017   Italy  Rioja  Errazuriz          NaN
# freq                         43    2646    325         40          NaN
# mean                        NaN     NaN    NaN        NaN     3.890148
# std                         NaN     NaN    NaN        NaN     0.308429
# min                         NaN     NaN    NaN        NaN     2.500000
# 25%                         NaN     NaN    NaN        NaN     3.700000
# 50%                         NaN     NaN    NaN        NaN     3.900000
# 75%                         NaN     NaN    NaN        NaN     4.100000
# max                         NaN     NaN    NaN        NaN     4.800000
#
#         NumberOfRatings        Price         Year
# count       8658.000000  8658.000000  8658.000000
# unique              NaN          NaN          NaN
# top                 NaN          NaN          NaN
# freq                NaN          NaN          NaN
# mean         409.761839    39.149789  2014.818434
# std          857.614243    84.963503     3.281252
# min           25.000000     3.550000  1988.000000
# 25%           66.000000    10.682500  2014.000000
# 50%          157.000000    18.200000  2016.000000
# 75%          400.750000    38.227500  2017.000000
# max        20293.000000  3410.790000  2019.000000

# %% [markdown]
# ### Exploring the PDFs

# %%
sns.histplot(data_no_mv['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %% [markdown]
# ### Dealing with outliers

# %%
# Declare a variable that will be equal to the 90th percentile of the 'Price' variable
q = data_no_mv['Price'].quantile(0.99)
# Then we can create a new df, with the condition that all prices must be below the 99 percentile of 'Price'
data_1 = data_no_mv[data_no_mv['Price']<q]
# In this way we have essentially removed the top 1% of the data about 'Price'
data_1.describe(include='all')
# Out:
#                            Name Country Region     Winery       Rating  \
# count                      8569    8569   8569       8569  8569.000000
# unique                     6645      30    622       2705          NaN
# top     Cabernet Sauvignon 2017   Italy  Rioja  Errazuriz          NaN
# freq                         43    2621    324         40          NaN
# mean                        NaN     NaN    NaN        NaN     3.883265
# std                         NaN     NaN    NaN        NaN     0.302179
# min                         NaN     NaN    NaN        NaN     2.500000
# 25%                         NaN     NaN    NaN        NaN     3.700000
# 50%                         NaN     NaN    NaN        NaN     3.900000
# 75%                         NaN     NaN    NaN        NaN     4.100000
# max                         NaN     NaN    NaN        NaN     4.800000
#
#         NumberOfRatings        Price         Year
# count       8569.000000  8569.000000  8569.000000
# unique              NaN          NaN          NaN
# top                 NaN          NaN          NaN
# freq                NaN          NaN          NaN
# mean         408.679543    32.801334  2014.887618
# std          858.340450    41.487180     3.145528
# min           25.000000     3.550000  1988.000000
# 25%           65.000000    10.630000  2014.000000
# 50%          157.000000    17.950000  2016.000000
# 75%          398.000000    37.450000  2017.000000
# max        20293.000000   368.470000  2019.000000

# %%
sns.histplot(data_1['Price'],kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.histplot(data_1['Rating'],kde=True)
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %%
sns.histplot(data_1['NumberOfRatings'])
# Out:
# <Axes: xlabel='NumberOfRatings', ylabel='Count'>

# %%
# Let's declare a variable that will be equal to the 99th percentile of the 'Price' variable
q = data_1['NumberOfRatings'].quantile(0.99)
# Then we can create a new df, with the condition that all prices must be below the 99 percentile of 'Price'
data_2 = data_1[data_1['NumberOfRatings']<q]
# In this way we have essentially removed the top 1% of the data about 'Price'
data_2.describe(include='all')
# Out:
#                            Name Country Region     Winery       Rating  \
# count                      8483    8483   8483       8483  8483.000000
# unique                     6590      30    620       2702          NaN
# top     Cabernet Sauvignon 2017   Italy  Rioja  Errazuriz          NaN
# freq                         42    2594    307         39          NaN
# mean                        NaN     NaN    NaN        NaN     3.882200
# std                         NaN     NaN    NaN        NaN     0.302133
# min                         NaN     NaN    NaN        NaN     2.500000
# 25%                         NaN     NaN    NaN        NaN     3.700000
# 50%                         NaN     NaN    NaN        NaN     3.900000
# 75%                         NaN     NaN    NaN        NaN     4.100000
# max                         NaN     NaN    NaN        NaN     4.800000
#
#         NumberOfRatings        Price         Year
# count       8483.000000  8483.000000  8483.000000
# unique              NaN          NaN          NaN
# top                 NaN          NaN          NaN
# freq                NaN          NaN          NaN
# mean         347.929506    32.771766  2014.884239
# std          519.387969    41.210753     3.151715
# min           25.000000     3.550000  1988.000000
# 25%           65.000000    10.650000  2014.000000
# 50%          154.000000    17.950000  2016.000000
# 75%          383.500000    37.615000  2017.000000
# max         3859.000000   368.470000  2019.000000

# %%
sns.histplot(data_2['NumberOfRatings'],kde=True)
# Out:
# <Axes: xlabel='NumberOfRatings', ylabel='Count'>

# %%
sns.histplot(data_2['Year'], kde=True)
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
# Outliers are on the low end, Taking off very old vintage wines
q = data_2['Year'].quantile(0.01)
data_3 = data_2[data_2['Year']>q]

# %%
sns.histplot(data_3['Year'], kde=True)
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
data_cleaned = data_3.reset_index(drop=True)

# %%
data_cleaned.describe(include='all')
# Out:
#                            Name Country Region     Winery       Rating  \
# count                      7955    7955   7955       7955  7955.000000
# unique                     6259      30    608       2619          NaN
# top     Cabernet Sauvignon 2017   Italy  Rioja  Errazuriz          NaN
# freq                         42    2503    298         35          NaN
# mean                        NaN     NaN    NaN        NaN     3.855952
# std                         NaN     NaN    NaN        NaN     0.287342
# min                         NaN     NaN    NaN        NaN     2.500000
# 25%                         NaN     NaN    NaN        NaN     3.700000
# 50%                         NaN     NaN    NaN        NaN     3.900000
# 75%                         NaN     NaN    NaN        NaN     4.100000
# max                         NaN     NaN    NaN        NaN     4.700000
#
#         NumberOfRatings        Price         Year
# count       7955.000000  7955.000000  7955.000000
# unique              NaN          NaN          NaN
# top                 NaN          NaN          NaN
# freq                NaN          NaN          NaN
# mean         346.562665    25.487449  2015.321433
# std          518.452575    22.166889     2.305199
# min           25.000000     3.550000  2006.000000
# 25%           65.000000    10.230000  2014.000000
# 50%          154.000000    16.900000  2016.000000
# 75%          382.000000    33.050000  2017.000000
# max         3814.000000   118.090000  2019.000000

# %% [markdown]
# # Part 2 - Checking the OLS assumptions

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize =(15,3)) #sharey -> share 'Price' as y
ax1.scatter(data_cleaned['Year'],data_cleaned['Price'])
ax1.set_title('Price and Year')
ax2.scatter(data_cleaned['Rating'],data_cleaned['Price'])
ax2.set_title('Price and Rating')
ax3.scatter(data_cleaned['NumberOfRatings'],data_cleaned['Price'])
ax3.set_title('Price and NumberOfRatings')

plt.show()

# %% [markdown]
# ### Relaxing the assumptions

# %%
# transform 'Price' with a log transformation
log_price = np.log(data_cleaned['Price'])

# Then we add it to our data frame
data_cleaned['log_price'] = log_price
data_cleaned
# Out:
#                                     Name        Country  \
# 0                           Pomerol 2011         France
# 1                             Lirac 2017         France
# 2     Erta e China Rosso di Toscana 2015          Italy
# 3                         Bardolino 2019          Italy
# 4         Ried Scheibner Pinot Noir 2016        Austria
# ...                                  ...            ...
# 7950                6th Sense Syrah 2016  United States
# 7951     Botrosecco Maremma Toscana 2016          Italy
# 7952                     Haut-Médoc 2010         France
# 7953                         Shiraz 2019      Australia
# 7954    Portillo Cabernet Sauvignon 2016      Argentina
#
#                        Region                     Winery  Rating  \
# 0                     Pomerol      Château La Providence     4.2
# 1                       Lirac         Château Mont-Redon     4.3
# 2                     Toscana                 Renzo Masi     3.9
# 3                   Bardolino                 Cavalchina     3.5
# 4                   Carnuntum                Markowitsch     3.9
# ...                       ...                        ...     ...
# 7950                     Lodi       Michael David Winery     3.8
# 7951          Maremma Toscana                Le Mortelle     4.0
# 7952               Haut-Médoc  Château Cambon La Pelouse     3.7
# 7953  South Eastern Australia                Yellow Tail     3.5
# 7954                  Tunuyán                  Salentein     3.4
#
#       NumberOfRatings  Price    Year  log_price
# 0                 100  95.00  2011.0   4.553877
# 1                 100  15.50  2017.0   2.740840
# 2                 100   7.45  2015.0   2.008214
# 3                 100   8.72  2019.0   2.165619
# 4                 100  29.15  2016.0   3.372455
# ...               ...    ...     ...        ...
# 7950              994  16.47  2016.0   2.801541
# 7951              995  20.09  2016.0   3.000222
# 7952              996  23.95  2010.0   3.175968
# 7953              998   6.21  2019.0   1.826161
# 7954              999   7.88  2016.0   2.064328
#
# [7955 rows x 9 columns]

# %%
# Build Scatter Plots with log_price
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize =(15,3)) #sharey -> share 'Price' as y
ax1.scatter(data_cleaned['Year'],data_cleaned['log_price'])
ax1.set_title('log_price and Year')
ax2.scatter(data_cleaned['Rating'],data_cleaned['log_price'])
ax2.set_title('log_price and Rating')
ax3.scatter(data_cleaned['NumberOfRatings'],data_cleaned['log_price'])
ax3.set_title('log_price and NumberOfRatings')


plt.show()

# %%
# Let's transform 'log_NumberOfRatings' with a log transformation
log_NumberOfRatings = np.log(data_cleaned['NumberOfRatings'])

# Then we add it to our data frame
data_cleaned['log_NumberOfRatings'] = log_NumberOfRatings
data_cleaned
# Out:
#                                     Name        Country  \
# 0                           Pomerol 2011         France
# 1                             Lirac 2017         France
# 2     Erta e China Rosso di Toscana 2015          Italy
# 3                         Bardolino 2019          Italy
# 4         Ried Scheibner Pinot Noir 2016        Austria
# ...                                  ...            ...
# 7950                6th Sense Syrah 2016  United States
# 7951     Botrosecco Maremma Toscana 2016          Italy
# 7952                     Haut-Médoc 2010         France
# 7953                         Shiraz 2019      Australia
# 7954    Portillo Cabernet Sauvignon 2016      Argentina
#
#                        Region                     Winery  Rating  \
# 0                     Pomerol      Château La Providence     4.2
# 1                       Lirac         Château Mont-Redon     4.3
# 2                     Toscana                 Renzo Masi     3.9
# 3                   Bardolino                 Cavalchina     3.5
# 4                   Carnuntum                Markowitsch     3.9
# ...                       ...                        ...     ...
# 7950                     Lodi       Michael David Winery     3.8
# 7951          Maremma Toscana                Le Mortelle     4.0
# 7952               Haut-Médoc  Château Cambon La Pelouse     3.7
# 7953  South Eastern Australia                Yellow Tail     3.5
# 7954                  Tunuyán                  Salentein     3.4
#
#       NumberOfRatings  Price    Year  log_price  log_NumberOfRatings
# 0                 100  95.00  2011.0   4.553877             4.605170
# 1                 100  15.50  2017.0   2.740840             4.605170
# 2                 100   7.45  2015.0   2.008214             4.605170
# 3                 100   8.72  2019.0   2.165619             4.605170
# 4                 100  29.15  2016.0   3.372455             4.605170
# ...               ...    ...     ...        ...                  ...
# 7950              994  16.47  2016.0   2.801541             6.901737
# 7951              995  20.09  2016.0   3.000222             6.902743
# 7952              996  23.95  2010.0   3.175968             6.903747
# 7953              998   6.21  2019.0   1.826161             6.905753
# 7954              999   7.88  2016.0   2.064328             6.906755
#
# [7955 rows x 10 columns]

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize =(15,3)) #sharey -> share 'Price' as y
ax1.scatter(data_cleaned['Year'],data_cleaned['log_price'])
ax1.set_title('log_price and Year')
ax2.scatter(data_cleaned['Rating'],data_cleaned['log_price'])
ax2.set_title('log_price and Rating')
ax3.scatter(data_cleaned['log_NumberOfRatings'],data_cleaned['log_price'])
ax3.set_title('log_price and log_NumberOfRatings')

plt.show()

# %%
# Let's transform 'Year' with a log transformation
log_year = np.log(data_cleaned['Year'])

# Then we add it to our data frame
data_cleaned['log_year'] = log_year
data_cleaned
# Out:
#                                     Name        Country  \
# 0                           Pomerol 2011         France
# 1                             Lirac 2017         France
# 2     Erta e China Rosso di Toscana 2015          Italy
# 3                         Bardolino 2019          Italy
# 4         Ried Scheibner Pinot Noir 2016        Austria
# ...                                  ...            ...
# 7950                6th Sense Syrah 2016  United States
# 7951     Botrosecco Maremma Toscana 2016          Italy
# 7952                     Haut-Médoc 2010         France
# 7953                         Shiraz 2019      Australia
# 7954    Portillo Cabernet Sauvignon 2016      Argentina
#
#                        Region                     Winery  Rating  \
# 0                     Pomerol      Château La Providence     4.2
# 1                       Lirac         Château Mont-Redon     4.3
# 2                     Toscana                 Renzo Masi     3.9
# 3                   Bardolino                 Cavalchina     3.5
# 4                   Carnuntum                Markowitsch     3.9
# ...                       ...                        ...     ...
# 7950                     Lodi       Michael David Winery     3.8
# 7951          Maremma Toscana                Le Mortelle     4.0
# 7952               Haut-Médoc  Château Cambon La Pelouse     3.7
# 7953  South Eastern Australia                Yellow Tail     3.5
# 7954                  Tunuyán                  Salentein     3.4
#
#       NumberOfRatings  Price    Year  log_price  log_NumberOfRatings  log_year
# 0                 100  95.00  2011.0   4.553877             4.605170  7.606387
# 1                 100  15.50  2017.0   2.740840             4.605170  7.609367
# 2                 100   7.45  2015.0   2.008214             4.605170  7.608374
# 3                 100   8.72  2019.0   2.165619             4.605170  7.610358
# 4                 100  29.15  2016.0   3.372455             4.605170  7.608871
# ...               ...    ...     ...        ...                  ...       ...
# 7950              994  16.47  2016.0   2.801541             6.901737  7.608871
# 7951              995  20.09  2016.0   3.000222             6.902743  7.608871
# 7952              996  23.95  2010.0   3.175968             6.903747  7.605890
# 7953              998   6.21  2019.0   1.826161             6.905753  7.610358
# 7954              999   7.88  2016.0   2.064328             6.906755  7.608871
#
# [7955 rows x 11 columns]

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize =(15,3)) #sharey -> share 'Price' as y
ax1.scatter(data_cleaned['log_year'],data_cleaned['log_price'])
ax1.set_title('log_price and log_year')
ax2.scatter(data_cleaned['Rating'],data_cleaned['log_price'])
ax2.set_title('log_price and Rating')

plt.show()

# %%
## drop log_NumberOfRatings and Price from the data
data_cleaned = data_cleaned.drop(['Price','log_NumberOfRatings'],axis=1)

# %%
data_cleaned.describe(include='all')
# Out:
#                            Name Country Region     Winery       Rating  \
# count                      7955    7955   7955       7955  7955.000000
# unique                     6259      30    608       2619          NaN
# top     Cabernet Sauvignon 2017   Italy  Rioja  Errazuriz          NaN
# freq                         42    2503    298         35          NaN
# mean                        NaN     NaN    NaN        NaN     3.855952
# std                         NaN     NaN    NaN        NaN     0.287342
# min                         NaN     NaN    NaN        NaN     2.500000
# 25%                         NaN     NaN    NaN        NaN     3.700000
# 50%                         NaN     NaN    NaN        NaN     3.900000
# 75%                         NaN     NaN    NaN        NaN     4.100000
# max                         NaN     NaN    NaN        NaN     4.700000
#
#         NumberOfRatings         Year    log_price     log_year
# count       7955.000000  7955.000000  7955.000000  7955.000000
# unique              NaN          NaN          NaN          NaN
# top                 NaN          NaN          NaN          NaN
# freq                NaN          NaN          NaN          NaN
# mean         346.562665  2015.321433     2.935047     7.608533
# std          518.452575     2.305199     0.757478     0.001145
# min           25.000000  2006.000000     1.266948     7.603898
# 25%           65.000000  2014.000000     2.325325     7.607878
# 50%          154.000000  2016.000000     2.827314     7.608871
# 75%          382.000000  2017.000000     3.498022     7.609367
# max         3814.000000  2019.000000     4.771447     7.610358

# %% [markdown]
# ### Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# we will explore only numerical data so far
variables = data_cleaned[['Rating','Year']]
vif = pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(variables.values, i) for i in range(variables.shape[1])]
vif["Features"] = variables.columns

# %%
vif
# Out:
#           VIF Features
# 0  179.563216   Rating
# 1  179.563216     Year

# %%
# vif is very high, we will check simple correlation
data_cleaned[['Rating', 'Year']].corr()
# Out:
#           Rating      Year
# Rating  1.000000 -0.271548
# Year   -0.271548  1.000000

# %%
plt.scatter(data_cleaned['Rating'],data_cleaned['Year'])

# %%
## Year and Rating do not have significant correlation, the VIF is high due to different data scale

# %%
data_cleaned[['Rating', 'Year']].describe()
# Out:
#             Rating         Year
# count  8225.000000  8225.000000
# mean      3.867733  2015.119149
# std       0.292629     2.648857
# min       2.500000  2005.000000
# 25%       3.700000  2014.000000
# 50%       3.900000  2016.000000
# 75%       4.100000  2017.000000
# max       4.700000  2019.000000

# %%
data_cleaned.dtypes
# Out:
# Name                object
# Country             object
# Region              object
# Winery              object
# Rating             float64
# NumberOfRatings      int64
# Year               float64
# log_price          float64
# log_year           float64
# dtype: object

# %%
data_cleaned[['Rating', 'Year']].isnull().sum()
# Out:
# Rating    0
# Year      0
# dtype: int64

# %% [markdown]
# ### Scale the inputs

# %%
from sklearn.preprocessing import StandardScaler
x = data_cleaned[['Rating', 'Year']].copy()
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %% [markdown]
# ### Check VIF on scaled data

# %%
vif = pd.DataFrame()
vif["Feature"] = x.columns
vif["VIF"] = [variance_inflation_factor(x_scaled, i) for i in range(x_scaled.shape[1])]

# %%
vif
# Out:
#   Feature       VIF
# 0  Rating  1.094142
# 1    Year  1.094142
